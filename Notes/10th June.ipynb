# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[df['Total Charges'].isnull()]['Tenure Months']
#
# NameError: name 'df' is not defined

# %%
dfdf[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfdf[df['Total Charges'].isnull()]['Tenure Months'].shape
#
# NameError: name 'dfdf' is not defined

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].fillna(0)
#fill null values with 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[df['Total Charges'].isnull()]['Tenure Months'].fillna(0)
#
# NameError: name 'df' is not defined

# %%
#data leakage - when the model has info that it should not have during training which leads to it not developing a logic that will help it predict 
# according to the problem statement b

# %%
drop_columns=['CustomerID','Count',' Country','State','Zip Code','Lat Long','Latitude','Longitude','Churn Label','Churn Score','CLTV','Churn Reason']

# %%
df.encoded = df.drop(['Churned Value'],axis=1)

# %%
#eda
#data cleaning
# machine learning
# train test split
#churn prediction model - meaning it will predict if a perso will leave the company or not
# use random forest classifier for this problem statement

# %%
df = df.drop(columns=drop_columns)

# %%
df.shape

# %%
df.info

# %%
rf_balanced=RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')
rf_balanced.fit(X_train,Y_train)
y_pred_balanced=rf_balanced.predict(X_test)
accuracy_balanced=accuracy_score(Y_test, y_pred_balanced)
cm_balanced=confusion_matrix(Y_test, y_pred_balanced)
print (accuracy_balanced,cm_balanced)
print (classification_report(Y_test, y_pred_balanced))
